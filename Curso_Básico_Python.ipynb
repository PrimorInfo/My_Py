# %% [markdown]
# <a href="https://colab.research.google.com/github/PrimorInfo/My_Py/blob/main/Curso_B%C3%A1sico_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import pandas as pd

lista_arquivo = os.listdir('/content/drive/MyDrive/CursoBásicoPython/Vendas')
display(lista_arquivo)
# Out:
# ['Vendas - Fortaleza.csv',
#  'Vendas - Goiás.csv',
#  'Vendas - São Paulo.csv',
#  'Vendas - Belo Horizonte.csv',
#  'Devolucoes - Rio de Janeiro.csv',
#  'Devolucoes - Salvador.csv',
#  'Devolucoes - Fortaleza.csv',
#  'Devolucoes - Goiás.csv',
#  'Vendas - Salvador.csv',
#  'Vendas - Rio de Janeiro.csv',
#  'Devolucoes - São Paulo.csv',
#  'Devolucoes - Porto Alegre.csv',
#  'Devolucoes - Belo Horizonte.csv',
#  'Vendas - Recife.csv',
#  'Vendas - Porto Alegre.csv',
#  'Vendas - Curitiba.csv',
#  'Devolucoes - Recife.csv',
#  'Devolucoes - Curitiba.csv']

# %%
tabela_total = pd.DataFrame()

for arquivo in lista_arquivo:
  #print(arquivo)
  #print('--')
   if 'vendas' in arquivo.lower():
    #print(f'/content/drive/MyDrive/CursoBásicoPython/Vendas/{arquivo}')

    tabela = pd.read_csv(f'/content/drive/MyDrive/CursoBásicoPython/Vendas/{arquivo}')
    #print(arquivo)
    #display(tabela)
    tabela_total = tabela_total.append(tabela)
display(tabela_total)

# %%
tabela_produtos = tabela_total.groupby('Produto').sum()
tabela_produtos = tabela_produtos[['Quantidade Vendida']].sort_values(by='Quantidade Vendida', ascending=False)
display(tabela_produtos)
# Out:
# <ipython-input-34-58ad5858923d>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   tabela_produtos = tabela_total.groupby('Produto').sum()
#             Quantidade Vendida
# Produto
# iPhone                    8974
# Televisão                 5931
# Notebook                  3249
# Android                   3183
# SmartWatch                2980
# Tablet                    2921
# Câmera                    2805

# %%
tabela_total['Faturamento'] = tabela_total['Quantidade Vendida'] * tabela_total['Preco Unitario']

tabela_faturamento = tabela_total.groupby('Produto').sum()
tabela_faturamento = tabela_faturamento[['Faturamento']].sort_values(by='Faturamento', ascending=False)
display(tabela_faturamento)
# Out:
# <ipython-input-38-de9f9d784f96>:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   tabela_faturamento = tabela_total.groupby('Produto').sum()
#             Faturamento
# Produto
# iPhone         47562200
# Televisão      14827500
# Notebook       11371500
# Android        10822200
# Câmera          5890500
# Tablet          4673600
# SmartWatch      4172000

# %%
tabela_lojas = tabela_total.groupby('Loja').sum()
tabela_lojas = tabela_lojas[['Faturamento']].sort_values(by='Faturamento', ascending=False)
display(tabela_lojas)
# Out:
# <ipython-input-41-ca5c680bd8ea>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   tabela_lojas = tabela_total.groupby('Loja').sum()
#                 Faturamento
# Loja
# São Paulo          22098300
# Rio de Janeiro     14867800
# Fortaleza          14087900
# Salvador           13111300
# Goiás               7441800
# Recife              7303000
# Curitiba            7060500
# Porto Alegre        6868600
# Belo Horizonte      6480300

# %%
import plotly.express as px

grafico = px.bar(tabela_lojas, x=tabela_lojas.index, y='Faturamento')
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
